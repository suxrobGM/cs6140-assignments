# %% [markdown]
# ## Installing Required Packages
#
# To ensure you have all the necessary packages for this notebook, you can install them using Poetry or manually via pip.
# First of all, you need to navigate to the directory containing the `pyproject.toml` file. This file contains the list of all the required packages for this notebook.
# Run the following command in your terminal to navigate to the directory from the root of the repository:
#
# ```bash
# cd assignments
# ```
#
# ### Using Poetry (Recommended)
#
# If you are using Poetry for dependency management, you can install the required packages by running the following single command in your terminal:
#
# ```bash
# poetry install
# ```
#
# This will install all the dependencies specified in your `pyproject.toml` file. To install poetry itself, you can read more in the [readme file](../../README.md).
#
# ### Manually via pip
#
# If you prefer to install the packages manually, you can use pip. You may need to set up a virtual environment before installing the packages. You can create a virtual environment by running:
#
# ```bash
# python -m venv .venv
# ```
#
# Then, you can activate the virtual environment. The command to activate the virtual environment depends on your operating system.
#
#
# You can find the required packages in the `pyproject.toml` file under the section `[tool.poetry.dependencies]` as well as `[tool.poetry.group.dev.dependencies]` and install them manually using pip.
# For example, to install pandas, you can run:
#
# ```bash
# pip install pandas
# ```
#
# Make sure to install any other required packages similarly.

# %% [markdown]
# # Tasks
# 1. Descriptive Statistics

# %%
from tasks import description_statistics

description_statistics()
# Out:
# Description Statistics
#
#
# City: Boston
#        minimum_nights  maximum_nights  number_of_reviews  review_scores_rating
# count     4325.000000     4325.000000        4325.000000           3326.000000
# mean        27.796763      597.905896          45.946127              4.713536
# std         36.266386      431.509974          91.367216              0.442439
# min          1.000000        3.000000           0.000000              1.000000
# 25%          1.000000      365.000000           1.000000              4.650000
# 50%         29.000000      365.000000           9.000000              4.830000
# 75%         32.000000     1125.000000          46.000000              4.980000
# max        600.000000     1125.000000         994.000000              5.000000
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from tasks import description_statistics
# ----> 3 description_statistics()
#
# File ~/code/cs6410/Assignment_1/cs6140-assignments/assignments/src/assignment1/tasks/description_statistics.py:10, in run()
#       8 for data in dataset:
#       9     city = data.city.replace("-", " ").capitalize()
# ---> 10     listings = pd.read_csv(data.listings_csv)
#      11     dataframe = listings[["price", "minimum_nights", "maximum_nights", "number_of_reviews", "review_scores_rating"]].describe()
#      12     print(f"\nCity: {city}")
#
# File ~/miniconda3/envs/usml_base_ds/lib/python3.10/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/usml_base_ds/lib/python3.10/site-packages/pandas/io/parsers/readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~/miniconda3/envs/usml_base_ds/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File ~/miniconda3/envs/usml_base_ds/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File parsers.pyx:843, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File parsers.pyx:904, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:879, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File parsers.pyx:890, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2058, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %% [markdown]
# 2. Distribution Analysis

# %%
from tasks import distribution_analysis

distribution_analysis()

# %% [markdown]
# 3. Correlation Analysis

# %%
from tasks import correlation_analysis

correlation_analysis()
# Out:
# Correlation Analysis
#
# boston Largest Positive Correlations
#                                              variables  correlation
# 293             minimum_nights, minimum_nights_avg_ntm     0.993108
# 344     minimum_minimum_nights, minimum_nights_avg_ntm     0.981092
# 0       host_listings_count, host_total_listings_count     0.979138
# 289             minimum_nights, minimum_minimum_nights     0.975939
# 656  calculated_host_listings_count, calculated_hos...     0.963236
#
# boston Largest Negative Correlations
#                                          variables  correlation
# 455      minimum_nights_avg_ntm, reviews_per_month    -0.418733
# 365      minimum_minimum_nights, reviews_per_month    -0.418593
# 314              minimum_nights, reviews_per_month    -0.414826
# 442  minimum_nights_avg_ntm, number_of_reviews_ltm    -0.384764
# 352  minimum_minimum_nights, number_of_reviews_ltm    -0.377003
#
# boston Top 5 Correlations Closeest to 0
#                                              variables  correlation
# 531                 availability_90, number_of_reviews    -0.000366
# 548           availability_365, number_of_reviews_l30d    -0.000575
# 499             availability_30, number_of_reviews_ltm    -0.001079
# 515                 availability_60, number_of_reviews    -0.001286
# 647  review_scores_location, calculated_host_listin...    -0.001697
# new-york-city Largest Positive Correlations
#                                           variables  correlation
# 253          minimum_nights, minimum_minimum_nights     0.980952
# 477                availability_60, availability_90     0.973546
# 257          minimum_nights, minimum_nights_avg_ntm     0.957555
# 308  minimum_minimum_nights, minimum_nights_avg_ntm     0.953353
# 459                availability_30, availability_60     0.939158
#
# new-york-city Largest Negative Correlations
#                                              variables  correlation
# 615  review_scores_value, calculated_host_listings_...    -0.206791
# 604  review_scores_communication, calculated_host_l...    -0.190619
# 63      host_total_listings_count, review_scores_value    -0.175993
# 616  review_scores_value, calculated_host_listings_...    -0.173035
# 162  accommodates, calculated_host_listings_count_p...    -0.172882
#
# new-york-city Top 5 Correlations Closeest to 0
#                                           variables  correlation
# 187          bathrooms, review_scores_communication    -0.000024
# 283          maximum_nights, minimum_nights_avg_ntm     0.000074
# 252                  minimum_nights, maximum_nights     0.000175
# 279          maximum_nights, minimum_minimum_nights     0.000241
# 364  minimum_maximum_nights, number_of_reviews_l30d     0.000281
# montreal Largest Positive Correlations
#                                              variables  correlation
# 392     minimum_maximum_nights, maximum_nights_avg_ntm     1.000000
# 414     maximum_maximum_nights, maximum_nights_avg_ntm     1.000000
# 390     minimum_maximum_nights, maximum_maximum_nights     1.000000
# 656  calculated_host_listings_count, calculated_hos...     0.974332
# 368     maximum_minimum_nights, minimum_nights_avg_ntm     0.962387
#
# montreal Largest Negative Correlations
#                                           variables  correlation
# 365       minimum_minimum_nights, reviews_per_month    -0.359404
# 314               minimum_nights, reviews_per_month    -0.321946
# 353  minimum_minimum_nights, number_of_reviews_l30d    -0.300392
# 352   minimum_minimum_nights, number_of_reviews_ltm    -0.287757
# 302          minimum_nights, number_of_reviews_l30d    -0.274689
#
# montreal Top 5 Correlations Closeest to 0
#                                          variables  correlation
# 108                             latitude, bedrooms    -0.000059
# 220              bathrooms, review_scores_accuracy    -0.000114
# 467  maximum_nights_avg_ntm, review_scores_checkin    -0.000141
# 404  minimum_maximum_nights, review_scores_checkin    -0.000141
# 426  maximum_maximum_nights, review_scores_checkin    -0.000141
# albany Largest Positive Correlations
#                                           variables  correlation
# 0    host_listings_count, host_total_listings_count     0.999844
# 380  maximum_minimum_nights, minimum_nights_avg_ntm     0.999357
# 355  minimum_minimum_nights, minimum_nights_avg_ntm     0.998363
# 352  minimum_minimum_nights, maximum_minimum_nights     0.997491
# 299          minimum_nights, maximum_minimum_nights     0.997237
#
# albany Largest Negative Correlations
#                                              variables  correlation
# 108                                latitude, longitude    -0.568624
# 167                  longitude, review_scores_location    -0.372183
# 143                               longitude, bathrooms    -0.253689
# 29         host_listings_count, review_scores_location    -0.252175
# 65   host_total_listings_count, review_scores_location    -0.251329
#
# albany Top 5 Correlations Closeest to 0
#                                              variables  correlation
# 379     maximum_minimum_nights, maximum_maximum_nights     0.000062
# 248                          bedrooms, availability_30     0.000305
# 191                    accommodates, number_of_reviews    -0.000451
# 375  minimum_minimum_nights, calculated_host_listin...    -0.000773
# 450     minimum_nights_avg_ntm, maximum_nights_avg_ntm    -0.001196
# washington-dc Largest Positive Correlations
#                                           variables  correlation
# 293          minimum_nights, minimum_nights_avg_ntm     0.984653
# 414  maximum_maximum_nights, maximum_nights_avg_ntm     0.980813
# 344  minimum_minimum_nights, minimum_nights_avg_ntm     0.963089
# 289          minimum_nights, minimum_minimum_nights     0.960733
# 0    host_listings_count, host_total_listings_count     0.956408
#
# washington-dc Largest Negative Correlations
#                                          variables  correlation
# 105                            latitude, longitude    -0.453033
# 163              longitude, review_scores_location    -0.354673
# 442  minimum_nights_avg_ntm, number_of_reviews_ltm    -0.324723
# 352  minimum_minimum_nights, number_of_reviews_ltm    -0.324605
# 301          minimum_nights, number_of_reviews_ltm    -0.317382
#
# washington-dc Top 5 Correlations Closeest to 0
#                                        variables  correlation
# 54    host_total_listings_count, availability_90     0.000403
# 29   host_listings_count, review_scores_location    -0.001051
# 223       bathrooms, review_scores_communication    -0.001374
# 243                    bedrooms, availability_90    -0.001408
# 219              bathrooms, review_scores_rating     0.001568

# %% [markdown]
# 4. Price Analysis

# %%
from tasks import price_analysis

price_analysis()

# %% [markdown]
# 5. Neighborhood Comparison

# %%
from tasks import neighborhood_comparison

neighborhood_comparison()

# %% [markdown]
# 6. Outlier Detection

# %%
from tasks import outlier_detection

outlier_detection()

# %% [markdown]
# 7. Text Length

# %%
from tasks import text_length

text_length()

# %% [markdown]
# 8. Keyword Extraction

# %%
from tasks import keyword_extraction

keyword_extraction()
