# %% [markdown]
# ## Installing Required Packages
#
# To ensure you have all the necessary packages for this notebook, you can install them using Poetry or manually via pip.
# First of all, you need to navigate to the directory containing the `pyproject.toml` file. This file contains the list of all the required packages for this notebook.
# Run the following command in your terminal to navigate to the directory from the root of the repository:
#
# ```bash
# cd assignments
# ```
#
# ### Using Poetry (Recommended)
#
# If you are using Poetry for dependency management, you can install the required packages by running the following single command in your terminal:
#
# ```bash
# poetry install
# ```
#
# This will install all the dependencies specified in your `pyproject.toml` file. To install poetry itself, you can read more in the [readme file](../../README.md).
#
# ### Manually via pip
#
# If you prefer to install the packages manually, you can use pip. You may need to set up a virtual environment before installing the packages. You can create a virtual environment by running:
#
# ```bash
# python -m venv .venv
# ```
#
# Then, you can activate the virtual environment. The command to activate the virtual environment depends on your operating system.
#
#
# You can find the required packages in the `pyproject.toml` file under the section `[tool.poetry.dependencies]` as well as `[tool.poetry.group.dev.dependencies]` and install them manually using pip.
# For example, to install pandas, you can run:
#
# ```bash
# pip install pandas
# ```
#
# Make sure to install any other required packages similarly.

# %% [markdown]
# # Tasks
# 1. Descriptive Statistics

# %%
from tasks import description_statistics

description_statistics()
# Out:
# Description Statistics
#
#
# City: Boston
#        minimum_nights  maximum_nights  number_of_reviews  review_scores_rating
# count     4325.000000     4325.000000        4325.000000           3326.000000
# mean        27.796763      597.905896          45.946127              4.713536
# std         36.266386      431.509974          91.367216              0.442439
# min          1.000000        3.000000           0.000000              1.000000
# 25%          1.000000      365.000000           1.000000              4.650000
# 50%         29.000000      365.000000           9.000000              4.830000
# 75%         32.000000     1125.000000          46.000000              4.980000
# max        600.000000     1125.000000         994.000000              5.000000
#
# City: New york city
#        minimum_nights  maximum_nights  number_of_reviews  review_scores_rating
# count     37541.00000    3.754100e+04        37541.00000          26001.000000
# mean         28.98162    5.831645e+04           25.23449              4.725152
# std          30.70918    1.108398e+07           60.17222              0.442850
# min           1.00000    1.000000e+00            0.00000              0.000000
# 25%          30.00000    1.500000e+02            0.00000              4.640000
# 50%          30.00000    3.650000e+02            3.00000              4.850000
# 75%          30.00000    1.125000e+03           21.00000              5.000000
# max        1250.00000    2.147484e+09         1941.00000              5.000000
#
# City: Montreal
#        minimum_nights  maximum_nights  number_of_reviews  review_scores_rating
# count     9539.000000     9539.000000        9539.000000           7739.000000
# mean        23.171716      490.613167          38.110703              4.695311
# std         35.074624     1094.832531          70.095785              0.461980
# min          1.000000        1.000000           0.000000              1.000000
# 25%          2.000000      365.000000           1.000000              4.620000
# 50%         31.000000      365.000000          10.000000              4.830000
# 75%         31.000000      550.000000          43.000000              4.980000
# max        500.000000    99999.000000         982.000000              5.000000
#
# City: Albany
#        minimum_nights  maximum_nights  number_of_reviews  review_scores_rating
# count      426.000000      426.000000         426.000000            366.000000
# mean         6.307512      521.443662          58.103286              4.766557
# std         21.856576      403.796329         104.452088              0.325399
# min          1.000000        1.000000           0.000000              3.000000
# 25%          1.000000      365.000000           4.000000              4.700000
# 50%          2.000000      365.000000          18.000000              4.860000
# 75%          3.000000     1125.000000          64.000000              4.970000
# max        365.000000     1125.000000         853.000000              5.000000
#
# City: Washington dc
#        minimum_nights  maximum_nights  number_of_reviews  review_scores_rating
# count     4928.000000     4928.000000        4928.000000           4183.000000
# mean        14.426339      471.089894          71.261567              4.766182
# std         28.401101      434.491271         108.524993              0.341227
# min          1.000000        1.000000           0.000000              0.000000
# 25%          1.000000       90.000000           3.000000              4.690000
# 50%          2.000000      365.000000          25.000000              4.860000
# 75%         31.000000     1125.000000          94.250000              4.960000
# max        701.000000     3650.000000         988.000000              5.000000

# %% [markdown]
# 2. Distribution Analysis

# %%
from tasks import distribution_analysis

distribution_analysis()

# %% [markdown]
# 3. Correlation Analysis

# %%
from tasks import correlation_analysis

correlation_analysis()

# %% [markdown]
# 4. Price Analysis

# %%
from tasks import price_analysis

price_analysis()

# %% [markdown]
# 5. Neighborhood Comparison

# %%
from tasks import neighborhood_comparison

neighborhood_comparison()

# %% [markdown]
# 6. Outlier Detection

# %%
from tasks import outlier_detection

outlier_detection()
# Out:
# Outliers in Boston:
#
# Outliers in price for Boston:
#        price
# 61     571.0
# 86     985.0
# 100    571.0
# 112    650.0
# 187    600.0
# ...      ...
# 4285  1000.0
# 4297   800.0
# 4301   975.0
# 4306   560.0
# 4313   609.0
#
# [241 rows x 1 columns]
# Outliers in minimum_nights for Boston:
#       minimum_nights
# 3                 91
# 4                 91
# 14                91
# 21                91
# 32                91
# ...              ...
# 4238              91
# 4254              91
# 4273              91
# 4283              91
# 4295              91
#
# [716 rows x 1 columns]
# Outliers in review_scores_rating for Boston:
#       review_scores_rating
# 6                     4.00
# 87                    4.00
# 166                   4.00
# 219                   3.71
# 221                   3.67
# ...                    ...
# 4256                  4.00
# 4262                  1.00
# 4263                  4.00
# 4269                  4.00
# 4275                  1.00
#
# [225 rows x 1 columns]
# Outliers in New york city:
#
# Outliers in price for New york city:
#         price
# 19      900.0
# 26      602.0
# 117     600.0
# 219     600.0
# 222     529.0
# ...       ...
# 37296   513.0
# 37310   646.0
# 37347  2000.0
# 37449   550.0
# 37516   700.0
#
# [1771 rows x 1 columns]
# Outliers in minimum_nights for New york city:
#        minimum_nights
# 0                  31
# 3                 120
# 12                  1
# 16                 60
# 26                  1
# ...               ...
# 37519             198
# 37524               5
# 37527              31
# 37537               2
# 37538               1
#
# [7406 rows x 1 columns]
# Outliers in review_scores_rating for New york city:
#        review_scores_rating
# 8                       4.0
# 39                      4.0
# 50                      2.0
# 70                      3.0
# 79                      4.0
# ...                     ...
# 37473                   4.0
# 37488                   3.0
# 37493                   4.0
# 37500                   4.0
# 37536                   3.8
#
# [1755 rows x 1 columns]
# Outliers in Montreal:
#
# Outliers in price for Montreal:
#         price
# 11      429.0
# 26    13294.0
# 71      429.0
# 96      696.0
# 124     400.0
# ...       ...
# 9443   3394.0
# 9450    500.0
# 9486    586.0
# 9496    392.0
# 9509    429.0
#
# [556 rows x 1 columns]
# Outliers in minimum_nights for Montreal:
#       minimum_nights
# 5                210
# 19               186
# 26                99
# 27                90
# 36                90
# ...              ...
# 9329              90
# 9333             120
# 9341              92
# 9361             365
# 9463              90
#
# [337 rows x 1 columns]
# Outliers in review_scores_rating for Montreal:
#       review_scores_rating
# 10                     4.0
# 208                    4.0
# 215                    3.0
# 227                    3.0
# 230                    4.0
# ...                    ...
# 9331                   2.0
# 9332                   4.0
# 9338                   3.0
# 9340                   4.0
# 9409                   4.0
#
# [532 rows x 1 columns]
# Outliers in Albany:
#
# Outliers in price for Albany:
#       price
# 4     305.0
# 15    243.0
# 20    430.0
# 23    275.0
# 29    570.0
# 64    274.0
# 78    245.0
# 85    240.0
# 101   507.0
# 127   600.0
# 131   250.0
# 140   300.0
# 164  1379.0
# 194   299.0
# 197   299.0
# 248   361.0
# 250   270.0
# 262   245.0
# 284   271.0
# 290   364.0
# 320   423.0
# 335  1750.0
# 342   356.0
# 387   282.0
# 391   250.0
# Outliers in minimum_nights for Albany:
#      minimum_nights
# 0                28
# 11               18
# 14               18
# 19               18
# 22               18
# ..              ...
# 393              20
# 399              30
# 404              28
# 407              60
# 409              30
#
# [68 rows x 1 columns]
# Outliers in review_scores_rating for Albany:
#      review_scores_rating
# 0                    3.56
# 71                   3.00
# 72                   3.96
# 112                  4.25
# 122                  4.25
# 138                  4.00
# 152                  3.00
# 187                  3.33
# 190                  3.25
# 191                  4.12
# 198                  3.67
# 227                  4.25
# 232                  4.20
# 247                  3.50
# 305                  4.00
# 330                  4.00
# 364                  4.00
# 369                  4.00
# 375                  4.00
# 377                  4.00
# 386                  4.00
# 388                  3.00
# 405                  3.00
# 414                  4.00
# Outliers in Washington dc:
#
# Outliers in price for Washington dc:
#       price
# 21    399.0
# 40    396.0
# 57    400.0
# 96    496.0
# 233   420.0
# ...     ...
# 4862  778.0
# 4863  677.0
# 4871  390.0
# 4872  444.0
# 4902  657.0
#
# [297 rows x 1 columns]
# Outliers in minimum_nights for Washington dc:
#       minimum_nights
# 11               120
# 30                90
# 35                90
# 41               150
# 55                90
# ...              ...
# 4574              90
# 4575              90
# 4788              90
# 4814              90
# 4899             180
#
# [184 rows x 1 columns]
# Outliers in review_scores_rating for Washington dc:
#       review_scores_rating
# 22                    4.20
# 50                    4.20
# 60                    4.22
# 72                    0.00
# 131                   4.00
# ...                    ...
# 4757                  4.00
# 4760                  3.80
# 4762                  3.00
# 4769                  4.00
# 4776                  4.14
#
# [218 rows x 1 columns]

# %% [markdown]
# 7. Text Length

# %%
from tasks import text_length

text_length()
# Out:
# City: Boston
# Correlation between word count and review scores: 0.023607324329069698
# Correlation between character count and review scores: 0.0299362544450027
#                  listing_id                                             name  \
# 0                      3781                        HARBORSIDE-Walk to subway
# 1                      3781                        HARBORSIDE-Walk to subway
# 2                      3781                        HARBORSIDE-Walk to subway
# 3                      3781                        HARBORSIDE-Walk to subway
# 4                      3781                        HARBORSIDE-Walk to subway
# ...                     ...                                              ...
# 198712  1176861035408746030         Cozy Boston studio with separate bedroom
# 198713  1176861035408746030         Cozy Boston studio with separate bedroom
# 198714  1177103248225483462   Stylish studio with room divider near downtown
# 198715  1177619455488589855                       Luxury South End 1 Bedroom
# 198716  1178933965841931292  Best Location, 1 bedroom Apartment, Beacon Hill
#
#                                                  comments  word_count  \
# 0       The apartment was as advertised and Frank was ...          20
# 1       It was a pleasure to stay at Frank's place. Th...          82
# 2       The apartment description is entirely faithful...          60
# 3       Thoroughly enjoyed my time at Frank's home. Ha...          66
# 4       Great value for the money! This location has e...         148
# ...                                                   ...         ...
# 198712  We felt right at home, the check in process wa...          35
# 198713  My stay was wonderful! The place was clean, co...          48
# 198714      Everything was beyond expectations. Thank you           6
# 198715  The unit was perfect. It was exactly what I wa...          67
# 198716                                Such a great spot!!           4
#
#         char_count  review_scores_rating
# 0              133                  4.96
# 1              414                  4.96
# 2              358                  4.96
# 3              365                  4.96
# 4              810                  4.96
# ...            ...                   ...
# 198712         207                  5.00
# 198713         306                  5.00
# 198714          45                  5.00
# 198715         418                  5.00
# 198716          19                  5.00
#
# [198717 rows x 6 columns]
# City: New york city
# Correlation between word count and review scores: 0.025610350288296703
# Correlation between character count and review scores: 0.03262098787451708
#                  listing_id                                             name  \
# 0                      2595                            Skylit Midtown Castle
# 1                      2595                            Skylit Midtown Castle
# 2                      2595                            Skylit Midtown Castle
# 3                      2595                            Skylit Midtown Castle
# 4                      2595                            Skylit Midtown Castle
# ...                     ...                                              ...
# 947323  1202281404451653124     Well-placed for Madison Square Garden events
# 947324  1202281439306897980            ADA-equipped room near Chelsea Market
# 947325  1202281541998087802  Restful king room walkable to dining & shopping
# 947326  1202281541998087802  Restful king room walkable to dining & shopping
# 947327  1202281551261078909   Sweet city views, equally stunning day & night
#
#                                                  comments  word_count  \
# 0       Notre séjour de trois nuits.\r<br/>Nous avons ...         124
# 1                                       Great experience.           2
# 2       I've stayed with my friend at the Midtown Cast...          90
# 3       We've been staying here for about 9 nights, en...          66
# 4       We had a wonderful stay at Jennifer's charming...          24
# ...                                                   ...         ...
# 947323                  Nice comfy place to get some rest           7
# 947324  It located in a great area that really close t...          30
# 947325  Works for a single night, however place felt a...          19
# 947326                                            Rip off           2
# 947327  The staff is not friendly and you have to pay ...          27
#
#         char_count  review_scores_rating
# 0              731                  4.68
# 1               17                  4.68
# 2              475                  4.68
# 3              366                  4.68
# 4              155                  4.68
# ...            ...                   ...
# 947323          33                  5.00
# 947324         173                  5.00
# 947325         109                  2.50
# 947326           7                  2.50
# 947327         134                  3.00
#
# [947328 rows x 6 columns]
# City: Montreal
# Correlation between word count and review scores: 0.02517011157132314
# Correlation between character count and review scores: 0.03135850468790216
#                  listing_id                                           name  \
# 0                    425582  Montreal Home Monthly only, ideal for couple!
# 1                    425582  Montreal Home Monthly only, ideal for couple!
# 2                    425582  Montreal Home Monthly only, ideal for couple!
# 3                    425582  Montreal Home Monthly only, ideal for couple!
# 4                    425582  Montreal Home Monthly only, ideal for couple!
# ...                     ...                                            ...
# 363533  1217008460821816729                       Fuji family hotel room 1
# 363534  1217008460821816729                       Fuji family hotel room 1
# 363535  1217008460821816729                       Fuji family hotel room 1
# 363536  1217008460821816729                       Fuji family hotel room 1
# 363537  1217285004181205141                     Top floor Unit in Montreal
#
#                                                  comments  word_count  \
# 0       We had a great time at this place.  The upstai...          62
# 1       I liked the place. Actually I was too busy in ...          44
# 2       We had a very nice stay.\r<br/>Corinne and her...          28
# 3       As a family with three teenagers Corinne's pla...         156
# 4       Corinne"s apartment was a lovely place to come...         103
# ...                                                   ...         ...
# 363533  J’ai bien aimé mon séjour chez Lois. Le logeme...          62
# 363534  Lois and her family were extremely kind and he...          42
# 363535  I would say that this has been my best AirBnB ...         113
# 363536  I really appreciated Lois’s place. She has a v...          36
# 363537  For my first airbnb experience, I have to say ...         100
#
#         char_count  review_scores_rating
# 0              323                   4.6
# 1              242                   4.6
# 2              185                   4.6
# 3              871                   4.6
# 4              598                   4.6
# ...            ...                   ...
# 363533         364                   5.0
# 363534         226                   5.0
# 363535         614                   5.0
# 363536         211                   5.0
# 363537         553                   4.0
#
# [363538 rows x 6 columns]
# City: Albany
# Correlation between word count and review scores: -0.023899814147312848
# Correlation between character count and review scores: -0.016960364578470423
#                 listing_id                                            name  \
# 0                  2992450                      Luxury 2 bedroom apartment
# 1                  2992450                      Luxury 2 bedroom apartment
# 2                  2992450                      Luxury 2 bedroom apartment
# 3                  2992450                      Luxury 2 bedroom apartment
# 4                  2992450                      Luxury 2 bedroom apartment
# ...                    ...                                             ...
# 24747  1201525324551556925                 Traveling Medical Professionals
# 24748  1223423894415302002                2BR condo 10 min walk to capitol
# 24749  1223423894415302002                2BR condo 10 min walk to capitol
# 24750  1223423894415302002                2BR condo 10 min walk to capitol
# 24751  1223982811498688622  Apartment w/ Deck in Albany, Walk to Downtown!
#
#                                                 comments  word_count  \
# 0      Large apartment; nice kitchen and bathroom. Ke...          69
# 1      This may be a little late, but just to say Ken...          92
# 2      The apartment was very clean and convenient to...          39
# 3      Kenneth was ready when I got there and arrange...         237
# 4      We were pleased to see how 2nd Street and the ...         242
# ...                                                  ...         ...
# 24747  My stay was great. Everyone was super friendly...          28
# 24748  The apartment was affordable, seemed clean, an...         183
# 24749  This was a good place to stay. I was just stay...         103
# 24750  If you need a place to crash for a day close t...          39
# 24751  Great place.  Amazing apartment.  Clean and co...          14
#
#        char_count  review_scores_rating
# 0             376                  3.56
# 1             492                  3.56
# 2             197                  3.56
# 3            1242                  3.56
# 4            1288                  3.56
# ...           ...                   ...
# 24747         178                  5.00
# 24748         998                  4.00
# 24749         553                  4.00
# 24750         190                  4.00
# 24751         101                  5.00
#
# [24752 rows x 6 columns]
# City: Washington dc
# Correlation between word count and review scores: 0.035229176347440744
# Correlation between character count and review scores: 0.04306686071665915
#                  listing_id                                             name  \
# 0                      3686                                  Vita's Hideaway
# 1                     32087  B&B Charm - Room 301 | Walk Dupont Circle Metro
# 2                     32087  B&B Charm - Room 301 | Walk Dupont Circle Metro
# 3                     32087  B&B Charm - Room 301 | Walk Dupont Circle Metro
# 4                     32087  B&B Charm - Room 301 | Walk Dupont Circle Metro
# ...                     ...                                              ...
# 351172  1174782697171003169    Apartment - Just 2 blocks from Supreme Court!
# 351173  1174847263231173602                            City Escape - DC Home
# 351174  1176086612220639801                                  Sapphire Sarouk
# 351175  1176908072393623018                   Georgetown Stay: Private entry
# 351176  1181139419019066786  Cozy Apartment at DC! Sun Filled & Comfortable!
#
#                                                  comments  word_count  \
# 0       Staying with Levita and her wonderful family w...          63
# 1       Very accommodating host, curteous, beautiful l...          17
# 2       Excellent! Will definitely stay here again. Gr...          13
# 3       Staying at American Guest House was the best d...          86
# 4       The guest house was very nice - most comfortab...          59
# ...                                                   ...         ...
# 351172  Very comfortable stay near Capitol Hill! The h...          23
# 351173  MoniQua is very responsive and helpful, the un...          14
# 351174  I loved everything about this adorable apartme...          66
# 351175                     Great location and cozy place!           5
# 351176  Mi familia y yo viajamos a Washington DC por u...          97
#
#         char_count  review_scores_rating
# 0              366                  4.64
# 1              123                  4.86
# 2               92                  4.86
# 3              488                  4.86
# 4              347                  4.86
# ...            ...                   ...
# 351172         140                  5.00
# 351173          92                  5.00
# 351174         388                  5.00
# 351175          30                  5.00
# 351176         587                  5.00
#
# [351177 rows x 6 columns]

# %% [markdown]
# 8. Keyword Extraction

# %%
from tasks import keyword_extraction

keyword_extraction()
